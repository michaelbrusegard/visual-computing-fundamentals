# %%
import numpy as np
import skimage
import utils
import pathlib

# %%
def otsu_thresholding(im: np.ndarray) -> int:
    """
        Otsu's thresholding algorithm that segments an image into 1 or 0 (True or False)
        The function takes in a grayscale image and outputs a threshold value

        args:
            im: np.ndarray of shape (H, W) in the range [0, 255] (dtype=np.uint8)
        return:
            (int) the computed thresholding value
    """
    assert im.dtype == np.uint8
    ### START YOUR CODE HERE ### (You can change anything inside this block) 
    # You can also define other helper functions
    # Compute normalized histogram
    # Normalized histogram
    # L = 256 (256 intensities)
    hist, _ = np.histogram(im, bins=256, range=(0,255))
    p = hist / np.sum(hist)

    # Get the cumulative sum from k=0 to L-1
    P1 = np.cumsum(p)

    # Cumulative mean
    m = np.cumsum(np.arange(256) * p)

    # Global mean
    m_g = m[-1]

    # Between-class variance
    sigma_2b = np.where(P1 * (1 - P1) == 0, 0, ((m_g * P1 - m)**2 ) / (P1 * (1 - P1)))

    sigma_2b_max = np.amax(sigma_2b)
    k_ss = [i for i, j in enumerate(sigma_2b) if j == sigma_2b_max]
    k_s = int(sum(k_ss) / len(k_ss))
    
    threshold = k_s
    
    return threshold
    ### END YOUR CODE HERE ###

# %%
if __name__ == "__main__":
    # DO NOT CHANGE
    impaths_to_segment = [
        pathlib.Path("thumbprint.png"),
        pathlib.Path("rice-shaded.png")
    ]
    for impath in impaths_to_segment:
        im = utils.read_image(impath)
        threshold = otsu_thresholding(im)
        print("Found optimal threshold:", threshold)

        # Segment the image by threshold
        segmented_image = (im >= threshold)
        assert im.shape == segmented_image.shape, "Expected image shape ({}) to be same as thresholded image shape ({})".format(
                im.shape, segmented_image.shape)
        assert segmented_image.dtype == bool, "Expected thresholded image dtype to be bool. Was: {}".format(
                segmented_image.dtype)

        segmented_image = utils.to_uint8(segmented_image)

        save_path = "{}-segmented.png".format(impath.stem)
        utils.save_im(save_path, segmented_image)
# Out:
# Reading image: images\thumbprint.png
# Found optimal threshold: 153
# Saving image to: image_processed\thumbprint-segmented.png
# Reading image: images\rice-shaded.png
# Found optimal threshold: 134
# Saving image to: image_processed\rice-shaded-segmented.png
# C:\Users\chris\AppData\Local\Temp\ipykernel_29200\3359733595.py:30: RuntimeWarning: invalid value encountered in divide
#   sigma_2b = np.where(P1 * (1 - P1) == 0, 0, ((m_g * P1 - m)**2 ) / (P1 * (1 - P1)))
